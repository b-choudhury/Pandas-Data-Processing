# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('covid-19-state-level-data.csv')

# %%
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
arr=np.array(df.state.unique())

# %%
lis=[]
for i in range(0,arr.size):
    df_1=by_state.get_group(arr[i])
    lis.append(df_1)

# %%
#Calculate Pearson correlation coefficient between state level cases vs deaths over time.

import scipy 
from scipy import stats

df_s=[]
for i in range(0,arr.size):
    df_s.append(
        {
          'State': arr[i],
          'PCC deaths vs cases': scipy.stats.pearsonr(lis[i]['deaths'],lis[i]['cases'])[0]
                         
            
        }
        
    )

# %%
pd.DataFrame.from_dict(df_s)
# Out:
#     PCC deaths vs cases                     State
# 0              0.995108                Washington
# 1              0.981876                  Illinois
# 2              0.998376                California
# 3              0.988223                   Arizona
# 4              0.979767             Massachusetts
# 5              0.968116                 Wisconsin
# 6              0.991509                     Texas
# 7              0.962509                  Nebraska
# 8              0.970453                      Utah
# 9              0.992332                    Oregon
# 10             0.989030                   Florida
# 11             0.955757                  New York
# 12             0.960607              Rhode Island
# 13             0.998997                   Georgia
# 14             0.972960             New Hampshire
# 15             0.931129            North Carolina
# 16             0.966920                New Jersey
# 17             0.987814                  Colorado
# ...
